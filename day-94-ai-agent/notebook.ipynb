# %% [markdown]
# ## Day 94 — Data Science AI Agent
#
# Agent loop:
# User → Agent decides → Tool → Observe result → Agent decides again → … → Final answer
#
# Tools:
# - summarize_dataset
# - get_column_info
# - calculate_statistics
# - calculate

# %%
from agent import run_agent

path = "train.csv"
q = "Summarize the dataset, then tell me the mean of pixel0 and whether it is greater than 50."
print(run_agent(q, path, max_turns=6))
# Out:
# The 'pixel0' column has an average value of 0.0, which is not greater than 50.

# %%
from agent import run_agent

path = "train.csv"
q = "Analyze the pixel0 column and tell me whether its average value is greater than 50."
print(run_agent(q, path, max_turns=4))
# Out:
# The 'pixel0' column has an average value of 0.0, which is not greater than 50.

# %%
import os
from pathlib import Path

print("CWD:", os.getcwd())
print(".env exists (CWD)?", (Path.cwd() / ".env").exists())

# Check where llm_client.py is
import llm_client
print("llm_client file:", llm_client.__file__)
print(".env exists (next to llm_client)?", (Path(llm_client.__file__).parent / ".env").exists())
# Out:
# CWD: e:\day 88\day-94-ai-agent
# .env exists (CWD)? True
# llm_client file: e:\day 88\day-94-ai-agent\llm_client.py
# .env exists (next to llm_client)? True

# %%
from agent import run_agent

path = "train.csv"
q = "Analyze the pixel0 column and tell me whether its average value is greater than 50."
print(run_agent(q, path))
# Out:
# The 'pixel0' column has an average value of 0.0, which is not greater than 50.

# %%
from tools import calculate_statistics

path = "train.csv"
print(calculate_statistics(path, "pixel0"))
# Out:
# {'column': 'pixel0', 'count': 42000, 'mean': 0.0, 'std': 0.0, 'min': 0.0, '25%': 0.0, '50%': 0.0, '75%': 0.0, 'max': 0.0}

# %%
from agent import run_agent

path = "train.csv"
q = "Analyze the pixel0 column and tell me whether its average value is greater than 50."
print(run_agent(q, path, max_turns=4))
# Out:
# The 'pixel0' column has an average value of 0.0, which is not greater than 50.

# %%
from agent import run_agent

path = "train.csv"
q = "Summarize the dataset, then tell me the mean of pixel0 and whether it is greater than 50."
print(run_agent(q, path, max_turns=6))
# Out:
# The 'pixel0' column has an average value of 0.0, which is not greater than 50.

# %%
from agent import run_agent

path = "train.csv"

# %%
q1 = "Summarize the dataset."
print("Question 1:", q1)
print("Answer 1:")
print(run_agent(q1, path, max_turns=4))
print("-" * 40)
# Out:
# Question 1: Summarize the dataset.
# Answer 1:
# This is a simple rule-based demo agent. It can handle questions about summarizing the dataset and analyzing the 'pixel0' column. For a full AI agent, connect a real LLM here.
# ----------------------------------------

# %%
q2 = "Analyze the pixel0 column and tell me whether its average value is greater than 50."
print("Question 2:", q2)
print("Answer 2:")
print(run_agent(q2, path, max_turns=4))
print("-" * 40)
# Out:
# Question 2: Analyze the pixel0 column and tell me whether its average value is greater than 50.
# Answer 2:
# The 'pixel0' column has an average value of 0.0, which is not greater than 50.
# ----------------------------------------

# %%
q3 = "Analyze the pixel0 column and tell me whether its average value is greater than 0."
print("Question 3:", q3)
print("Answer 3:")
print(run_agent(q3, path, max_turns=4))
print("-" * 40)
# Out:
# Question 3: Analyze the pixel0 column and tell me whether its average value is greater than 0.
# Answer 3:
# The 'pixel0' column has an average value of 0.0.
# ----------------------------------------

# %%
q4 = "Summarize the dataset, then tell me the mean of pixel0 and whether it is greater than 50."
print("Question 4:", q4)
print("Answer 4:")
print(run_agent(q4, path, max_turns=6))
print("-" * 40)
# Out:
# Question 4: Summarize the dataset, then tell me the mean of pixel0 and whether it is greater than 50.
# Answer 4:
# The 'pixel0' column has an average value of 0.0, which is not greater than 50.
# ----------------------------------------

# %%
from tools import (
    summarize_dataset,
    get_column_info,
    calculate_statistics,
    calculate,
)

path = "train.csv"

print("1. DATASET SUMMARY")
print(summarize_dataset(path))

print("\n2. COLUMN INFORMATION")
print(get_column_info(path, "pixel0"))

print("\n3. COLUMN STATISTICS")
stats = calculate_statistics(path, "pixel0")
print(stats)

print("\n4. COMPARISON USING REAL MEAN")
print(calculate("mean > 50", {"mean": stats["mean"]}))
# Out:
# 1. DATASET SUMMARY
# ...
